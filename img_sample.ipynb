# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = cv2.imread("png/castle/3762.png")

# %%
plt.imshow(img)

# %%
img2 = cv2.resize(img, (128, 128))

# %%
plt.imshow(img2)
